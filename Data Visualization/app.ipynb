# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing Dataset

# %%
titanic_df = pd.read_csv('Titanic-Dataset.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Information : lots of missing data in Cabin and Age

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Visualization of missing data

# %%
sns.heatmap(titanic_df.isnull(),yticklabels=False, cbar=False, cmap='Reds')
# Out:
# <Axes: >

# %% [markdown]
# Survival-rate Insights : 38.384 %
# Survived : 1
# Not Survived : 0

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Visualization of Survivals

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=titanic_df, hue='Survived',palette=['red','green'])
plt.xticks([0,1],['Not Survived','Survived'])
# Out:
# ([<matplotlib.axis.XTick at 0x22c7683c690>,
# ...
#  [Text(0, 0, 'Not Survived'), Text(1, 0, 'Survived')])

# %% [markdown]
# Visualization of Male vs Female

# %%
sns.countplot(x='Sex',data=titanic_df, hue='Sex', palette=['blue','pink'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# Gender Based Survivals
#
# More Females were survived as compared to Males

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=titanic_df, hue='Sex', palette=['blue','pink'])
plt.xticks([0,1],['Not Survived','Survived'])
# Out:
# ([<matplotlib.axis.XTick at 0x22c768f3c50>,
# ...
#  [Text(0, 0, 'Not Survived'), Text(1, 0, 'Survived')])

# %% [markdown]
# Classes

# %%
sns.countplot(x='Pclass',data=titanic_df,hue='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# Class Based Survival
#
# lower-class Passengers had a lower likelihood of Survival

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=titanic_df, hue='Pclass')
plt.xticks([0,1],['Not Survived','Survived'])
# Out:
# ([<matplotlib.axis.XTick at 0x22c769f5090>,
# ...
#  [Text(0, 0, 'Not Survived'), Text(1, 0, 'Survived')])

# %% [markdown]
# Male & Females in each class

# %%
sns.countplot(x='Sex',data=titanic_df,hue='Pclass')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.histplot(x='Age',data=titanic_df,bins=80)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Family Members Survival

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=titanic_df, hue='SibSp',palette='deep')
plt.xticks([0,1],['Not Survived','Survived'])
# Out:
# ([<matplotlib.axis.XTick at 0x22c77ad2490>,
# ...
#  [Text(0, 0, 'Not Survived'), Text(1, 0, 'Survived')])

# %% [markdown]
# City & Class

# %%
sns.set_style('whitegrid')
sns.countplot(x='Embarked',data=titanic_df, hue='Pclass',palette='deep')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>
